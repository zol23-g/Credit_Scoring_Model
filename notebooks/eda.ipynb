# %% [markdown]
# ## Task 1

# %%
import sys
import os
sys.path.append('..')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scripts.logger import setup_logger
from scripts.eda import EDA

# %% [markdown]
# ## Task 2

# %%
# Load dataset
from scripts.data_loader import DataLoader
data_loader = DataLoader('../data/data.csv')
df = data_loader.load_data()
# Out:
# 2024-10-03 21:17:21,718 - scripts.logger - INFO - Data loaded successfully from ../data/data.csv

# %%
df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
#let's have a description of the variables here to keep refering to them
feature_desc = pd.read_csv('../data/Xente_Variable_Definitions.csv')
feature_desc
# Out:
#              Column Name                                         Definition
# 0          TransactionId         Unique �transaction identifier on platform
# 1                BatchId  Unique number assigned to a batch of transacti...
# 2              AccountId  Unique number identifying the customer on plat...
# 3         SubscriptionId  Unique number identifying the customer subscri...
# 4             CustomerId              Unique identifier attached to Account
# 5           CurrencyCode                                   Country currency
# 6            CountryCode             Numerical geographical code of country
# 7             ProviderId                   Source provider of Item �bought.
# 8              ProductId                            Item name being bought.
# 9        ProductCategory  ProductIds are organized into these broader pr...
# 10             ChannelId  Identifies if customer used web,Android, IOS, ...
# ...

# %%
eda = EDA(df)

# %%
# Overview of the data
overview = eda.overview()
print("Data Overview:\n", overview)
# Out:
# Data Overview:
#  {'shape': (95662, 16), 'columns': Index(['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId',
#        'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId',
#        'ProductCategory', 'ChannelId', 'Amount', 'Value',
#        'TransactionStartTime', 'PricingStrategy', 'FraudResult'],
#       dtype='object'), 'data_types': TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object}

# %%
# Summary Statistics
summary_stats = eda.summary_statistics()
print("Summary Statistics:\n", summary_stats)
# Out:
# 2024-10-03 20:50:58,033 - scripts.logger - INFO - Calculating summary statistics...
# 2024-10-03 20:50:58,033 - scripts.logger - INFO - Calculating summary statistics...
# 2024-10-03 20:50:58,033 - scripts.logger - INFO - Calculating summary statistics...
# Summary Statistics:
#         CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# ...

# %%
# Distribution of Numerical Features
numerical_features = df.select_dtypes(include=['float64', 'int64']).columns
for feature in numerical_features:
    eda.plot_distribution(feature)
# Out:
# 2024-10-03 20:51:51,093 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:51:51,093 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:51:51,093 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:51:51,666 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:51:51,666 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:51:51,666 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:53:05,187 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:53:05,187 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:53:05,187 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:54:26,314 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:54:26,314 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:54:26,314 - scripts.logger - INFO - Distribution Plot...
# 2024-10-03 20:54:28,230 - scripts.logger - INFO - Distribution Plot...
# ...

# %%
# Distribution of Categorical Features
categorical_features = df.select_dtypes(include=['object']).columns
for feature in categorical_features:
    eda.plot_categorical_distribution(feature)
# Out:
# 2024-10-03 21:19:46,702 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 21:19:46,702 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 21:48:57,810 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 21:48:57,810 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:26:38,991 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:26:38,991 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:27:25,591 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:27:25,591 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:28:29,284 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:28:29,284 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:29:22,688 - scripts.logger - INFO - Categorical distribution...
# 2024-10-03 22:29:22,688 - scripts.logger - INFO - Categorical distribution...
# ...
